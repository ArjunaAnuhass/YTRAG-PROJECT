# %% [markdown]
# ### Data Ingestion

# %%
### Document Structure

from langchain_core.documents import Document

# %%
doc=Document(
    page_content="this is the main text content I am using to create RAG",
    metadata={
        "source": "example.txt",
        "pages": 1,
        "author": "Krish Naik",
        "date_created": "2025-01-01"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Krish Naik', 'date_created': '2025-01-01'}, page_content='this is the main text content I am using to create RAG')

# %%
## create a simple txt file

import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts={
   "../data/text_files/python_intro.txt":"""Python Programming Introduction,

Python is a high-level, interpreted programming language known for its simplicity and readability.\n",
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular\n",
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",

    "../data/text_files/machine_learning.txt":"""Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems

    """
}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("Sample text files created")
# Out:
# Sample text files created

# %%
### TextLoader

from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction,\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\n",\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\n",\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
### Directory Loader

from langchain_community.document_loaders import DirectoryLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", ## Pattern to match files
    loader_cls= TextLoader, ## loader class to use
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=False
)

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction,\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\n",\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\n",\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.'),
#  Document(metadata={'source': '../data/text_files/machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n    ')]

# %%
### PDF Loader

from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader
from langchain_community.document_loaders import DirectoryLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", ## Pattern to match files
    loader_cls=PyMuPDFLoader, ## loader class to use
    show_progress=False
)

pdf_documents=dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2025-04-29T10:48:20+00:00', 'source': '../data/pdf/Arjuna Anuhass Resume.pdf', 'file_path': '../data/pdf/Arjuna Anuhass Resume.pdf', 'total_pages': 2, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-04-29T10:48:20+00:00', 'trapped': '', 'modDate': 'D:20250429104820Z', 'creationDate': "D:20250429104820+00'00'", 'page': 0}, page_content='Arjuna Anuhass. \nFULLSTACK ENGINEER | FRONTEND DEVELOPER \nColombo, Sri Lanka | (+94)76 731 7368 | anuhass2017@gmail.com \nLinkedIn: https://www.linkedin.com/in/arjuna-anuhass-0b768b254/ \nGitHub: https://github.com/ArjunaAnuhass \nProfile Summary \n \nEnthusiastic and Software Engineering graduate with hands-on experience in university-based projects. \nGood in Java Spring Boot for backend development and React.js for frontend applications. \nPassionate about building scalable and efficient software solutions. Eager to apply my skills in a \nprofessional environment and gain industry experience through an internship. \nCore Competencies \n \n\uf0b7 \nReact.js \n\uf0b7 \nJavaScript, TypeScript \n\uf0b7 \nRedux \n\uf0b7 \nRest APIs \n\uf0b7 \nSoftware Architecture \n\uf0b7 \nJava \n\uf0b7 \nSpring Boot \n\uf0b7 \nDebugging Skills \n\uf0b7 \nMySQL/ MongoDB \n\uf0b7 \nRest API \n\uf0b7 \nGit \n\uf0b7 \nNode / Node.js \n\uf0b7 \nExpress.js \n\uf0b7 \nPython \n\uf0b7 \nAI & ML \n\uf0b7 \nAgile, Jira \n\uf0b7 \nUI/UX, SCSS, Figma \n\uf0b7 \nHTML, CSS'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2025-04-29T10:48:20+00:00', 'source': '../data/pdf/Arjuna Anuhass Resume.pdf', 'file_path': '../data/pdf/Arjuna Anuhass Resume.pdf', 'total_pages': 2, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-04-29T10:48:20+00:00', 'trapped': '', 'modDate': 'D:20250429104820Z', 'creationDate': "D:20250429104820+00'00'", 'page': 1}, page_content='Education \n \nBSc. In Software Engineering (Hons) \nCardiff Metropolitan University (UK) \nInternational College of Business and Technology (ICBT), Colombo, Sri Lanka March  \nMajor: Web Development | Minor: Machine Learning \nOverall Grade: 2.1 – 2nd Class Upper Division \nProjects \n \nTNA AGENCIES (REAL ESTATE WEBSITE) \n \nThis is my Software Engineering final project. This project has machine learning(minor) and web \ndevelopment(major) parts. Web applications were developed utilizing the MVC architecture to manage \nefficiency. The application was implemented using Java, Spring Boot Framework, JavaScript, React \nLibrary, ES6, Python, and MySQL database technologies. Add a real estate advertisement, update an ad, \nremove an advertisement, add to a favorite advertisement, authentication, authorization, and admin panel \nare the features of this web application. Additionally, a user can estimate a house or property price by \nproviding the required details. \n \nONLINE FOOD ORDERING WEBSITE \n \nThis online food ordering web application was developed using Java Spring Boot for the backend, the \nReact JavaScript library (ES6) for the frontend, and MySQL as the database, following the MVC \narchitectural pattern. The system supports three primary user roles, restaurant owner, customer, and \nadmin. Restaurant owners can manage their restaurant profiles, including adding, updating, or deleting \nrestaurant details, as well as handling order management. Customers can explore a variety of \nrestaurants, place orders, complete online payments securely through the Stripe payment gateway, and \ntrack their orders in real-time. The platform provides a seamless and user-friendly experience, ensuring \nefficient interaction between restaurant and customer while giving admins full control over the system. \n \nSkills & abilities \n \n\uf0b7 \nProblem solving \n\uf0b7 \nCommunication \n\uf0b7 \nLeadership  \n\uf0b7 \nQuick Leaner \n \nPersonal Information \n \nLANGUAGE: \n\uf0b7 \nEnglish \n\uf0b7 \nSinhala (Native)'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': '', 'creationdate': '', 'source': '../data/pdf/Arjuna_Anuhass_Associate.pdf', 'file_path': '../data/pdf/Arjuna_Anuhass_Associate.pdf', 'total_pages': 2, 'format': 'PDF 1.7', 'title': 'Resume - Arjuna Anuhass', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content='ARJUNA ANUHASS\nColombo, Sri Lanka \xa0|\xa0 (+94) 76 731 7368 \xa0|\xa0 anuhass2017@gmail.com\nlinkedin.com/in/arjuna-anuhass-0b768b254 \xa0|\xa0 github.com/ArjunaAnuhass\nPROFESSIONAL SUMMARY\nResults-oriented Software Engineer with a strong foundation in modern JavaScript/TypeScript ecosystems, React,\nand Next.js. Proven track record of designing high-performance headless e-commerce storefronts, architecting\nCMS schemas, and optimizing web applications for maximum speed, SEO, and responsiveness. Hands-on\nexperience across the entire Software Development Lifecycle (SDLC) within Agile globally distributed team setups.\nCORE COMPETENCIES\nProgramming Languages\nJavaScript (ES6+), TypeScript, Java, Python, HTML5, CSS3\nFrameworks & Libraries\nReact.js, Next.js, Node.js, Express.js, Java Spring Boot, Tailwind CSS\nE-commerce & CMS\nShopify Hydrogen, Sanity CMS, Headless Architecture\nDatabases & Tools\nMySQL, MongoDB, Git, GitHub, Vite, Jira, Agile Methodologies, Figma\nSoftware Engineering\nAPI Integration, Web Performance Optimization, System Design, Component Architecture\nPROFESSIONAL EXPERIENCE\nDLAD Software Solutions Pvt Ltd\nMay 2025 – Jan 2026 | Sri Lanka\nSoftware Engineering Intern\nDeveloped and optimized production-grade headless e-commerce storefronts utilizing Shopify Hydrogen and\nNext.js, driving measurable web performance optimization.\nArchitected modular content schemas and managed data fetching with Sanity CMS, gaining deep exposure to\ncomposable architectures.\nCollaborated within an Agile team structure on international, cross-border projects ensuring multi-lingual\nmetadata integration and responsive UI components.\nConfigured development systems using Vite and engineered dynamic URL handlers to maintain strict frontend\nuser interface state consistency.\nParticipated throughout the full Software Development Lifecycle (SDLC), troubleshooting and debugging\nfrontend systems to optimize rendering speeds.\nSELECTED PROJECTS\nTNA Agencies — Real Estate Platform\nFull-Stack Developer\nDesigned and built a full-stack web application following modern MVC architecture patterns using Java Spring\nBoot, React, and MySQL.\nIntegrated a custom Machine Learning module backend service to deliver automated property price estimations\non the client interface.\nImplemented frontend security best practices, utilizing secure user authentication, role-based authorization,\nand an administrative dashboard.\n• \n• \n• \n• \n• \n• \n• \n• \nPage 1 of 2'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': '', 'creationdate': '', 'source': '../data/pdf/Arjuna_Anuhass_Associate.pdf', 'file_path': '../data/pdf/Arjuna_Anuhass_Associate.pdf', 'total_pages': 2, 'format': 'PDF 1.7', 'title': 'Resume - Arjuna Anuhass', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 1}, page_content='Online Food Ordering Website — Multi-Tenant Platform\nFull-Stack Developer\nEngineered a multi-role user system (Customer, Restaurant Owner, Admin) utilizing a decoupled React\nfrontend and a Spring Boot backend API.\nIntegrated Stripe Payment Gateway securely to process real-time, encrypted online transactions.\nDeveloped dynamic tracking systems for order management, improving asynchronous user state updates.\nTEA-DROP-HYDROGEN-3 — Composable Storefront\nFrontend Developer\nBuilt a highly scalable, high-performance web storefront utilizing the Shopify Hydrogen framework and Tailwind\nCSS.\nOptimized web performance focusing on application loading speeds, SEO best practices, and customized\nheadless CMS components.\nEDUCATION\nBSc. (Hons) in Software Engineering\nCardiff Metropolitan University (UK)\nGrade: 2.1 (Second Class Upper Division)\nMajor: Web Development | Minor: Machine Learning \nLANGUAGES\nEnglish: Professional Proficiency\nSinhala: Native \n• \n• \n• \n• \n• \nPage 2 of 2'),
#  Document(metadata={'producer': 'Skia/PDF m148 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '../data/pdf/Arjuna Anuhass Associate Resume.pdf', 'file_path': '../data/pdf/Arjuna Anuhass Associate Resume.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': 'Untitled document', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content='Arjuna Anuhass \nAssociate Software Engineer | Full-Stack Developer, Sri Lanka | (+94) 76 731 7368 | \nanuhass2017@gmail.com \nLinkedIn | GitHub \nProfessional Summary \nResults-oriented Associate Software Engineer with a strong foundation in React, Next.js, and \nTypeScript. Recently completed a Software Engineering Internship at DLAD Software \nSolutions, gaining hands-on experience in building high-performance, headless e-commerce \nstorefronts using Shopify Hydrogen and Sanity CMS. Proven ability to deliver scalable web \nsolutions using Java Spring Boot and modern frontend frameworks. Committed to clean code, \nresponsive design, and efficient problem-solving within Agile environments. \nCore Competencies \n●\u200b Frontend: React.js, Next.js, TypeScript, JavaScript (ES6+), Redux, Tailwind CSS \n●\u200b Backend: Java (Spring Boot), Node.js, Express.js, REST APIs, Python \n●\u200b E-commerce & CMS: Shopify Hydrogen, Sanity CMS, Headless Architecture \n●\u200b Databases: MySQL, MongoDB \n●\u200b Tools & Methodology: Git, Jira, Agile, Vite, Figma \nProfessional Experience \nSoftware Engineering Intern | DLAD Software Solutions Pvt Ltd, May 2025 – Jan 2026 \n●\u200b Developed and optimized real-world headless e-commerce storefronts using Shopify \nHydrogen and Next.js. \n●\u200b Architected content schemas and implemented efficient data fetching using Sanity CMS. \n●\u200b Collaborated on international projects, ensuring seamless multi-lingual metadata \nintegration and responsive user interfaces. \n●\u200b Configured development environments using Vite and ensured UI state consistency by \nderiving navigation logic directly from URL handlers. \nSelected Projects \nTNA Agencies (Real Estate Platform) \n●\u200b Developed a full-stack application using Java Spring Boot, React, and MySQL \nfollowing MVC architecture. \n●\u200b Integrated a Machine Learning module to provide automated property price \nestimations. \n●\u200b Implemented secure user authentication, authorization, and a comprehensive admin \ndashboard.'),
#  Document(metadata={'producer': 'Skia/PDF m148 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '../data/pdf/Arjuna Anuhass Associate Resume.pdf', 'file_path': '../data/pdf/Arjuna Anuhass Associate Resume.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': 'Untitled document', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 1}, page_content='Online Food Ordering Website \n●\u200b Built a multi-role system (Customer, Restaurant Owner, Admin) using Spring Boot and \nReact. \n●\u200b Integrated the Stripe Payment Gateway for secure, real-time online transactions. \n●\u200b Designed features for order management and real-time order tracking. \nTEA-DROP-HYDROGEN-3 \n●\u200b Developed a high-performance storefront utilizing the Shopify Hydrogen framework and \nTailwind CSS. \n●\u200b Focused on SEO, system optimization, and custom headless CMS integrations to \nenhance user experience. \nEducation \nBSc. (Hons) in Software Engineering \nCardiff Metropolitan University (UK) \nGrade: 2.1 (Second Class Upper Division) \nMajor: Web Development | Minor: Machine Learning \nLanguages \n●\u200b English: Professional Proficiency \n●\u200b Sinhala: Native')]

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document
